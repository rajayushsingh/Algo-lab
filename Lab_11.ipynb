# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %%
import math

def tsp_with_path(graph):
    n = len(graph)

    dp = [[-1] * (1 << n) for _ in range(n)]

    parent = [[-1] * (1 << n) for _ in range(n)]

    def visit(city, mask):

        if mask == (1 << n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        res = float('inf')
        best_next_city = -1

        for next_city in range(n):

            if (mask & (1 << next_city)) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1 << next_city))
                if new_cost < res:
                    res = new_cost
                    best_next_city = next_city

        dp[city][mask] = res
        parent[city][mask] = best_next_city
        return res


    min_cost = visit(0, 1)

    path = []
    curr_city = 0
    curr_mask = 1

    while curr_city != -1:
        path.append(curr_city)
        curr_city = parent[curr_city][curr_mask]
        if curr_city != -1:
            curr_mask |= (1 << curr_city)

    path.append(0)
    return min_cost, path

def get_user_input():
    print("--- Travelling Salesman Problem (DP) ---")
    n = int(input("Enter the number of cities: "))
    print(f"Enter the adjacency matrix ({n}x{n}):")

    grid = []
    for i in range(n):
        row = list(map(int, input(f"Row {i} (separated by spaces): ").split()))
        grid.append(row)
    return grid

try:
    user_graph = get_user_input()
    cost, route = tsp_with_path(user_graph)

    print("\n--- Results ---")
    print(f"Minimum travelling cost: {cost}")
    print(f"Path taken: {' -> '.join(map(str, route))}")
except Exception as e:
    print("\nError: Please ensure the input is a valid square matrix.")
# Out:
# --- Travelling Salesman Problem (DP) ---
# Enter the number of cities: 4
# Enter the adjacency matrix (4x4):
# Row 0 (separated by spaces): 1
# Row 1 (separated by spaces): 2
# Row 2 (separated by spaces): 3
# Row 3 (separated by spaces): 3
#
# Error: Please ensure the input is a valid square matrix.

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities
